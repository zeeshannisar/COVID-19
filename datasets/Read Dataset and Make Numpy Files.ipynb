# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
import numpy as np
from keras.preprocessing.image import load_img, img_to_array
from tqdm.notebook import tqdm

os.chdir('/content/drive/My Drive/GitHub Repositories/COVID-19')
dataDir = './datasets'
directories = os.listdir(dataDir)

def Read_Images_and_Make_Numpy_Files(directory):
  images = []
  labels = []
  classes = os.listdir(os.path.join(dataDir, directory))
  print('{} Directory Classes: {}'.format(directory, classes))
  for class_ in classes:
    if class_ == '0:Normal':
      print('Reading Data for {} class'.format(class_))
      imageNames = os.listdir(os.path.join(dataDir, directory, class_))
      for imgName in tqdm(imageNames):
        img = load_img(os.path.join(dataDir, directory, class_, imgName), target_size=(224, 224), color_mode='rgb', interpolation='lanczos')
        img_array = img_to_array(img, data_format='channels_last', dtype='float32')
        images.append(img_array)
        labels.append(0)
    elif class_ == '1:Bacteria':
      print('Reading Data for {} class'.format(class_))
      imageNames = os.listdir(os.path.join(dataDir, directory, class_))
      for imgName in tqdm(imageNames):
        img = load_img(os.path.join(dataDir, directory, class_, imgName), target_size=(224, 224), color_mode='rgb', interpolation='lanczos')
        img_array = img_to_array(img, data_format='channels_last', dtype='float32')
        images.append(img_array)
        labels.append(1)
    elif class_ == '2:Viral':
      print('Reading Data for {} class'.format(class_))
      imageNames = os.listdir(os.path.join(dataDir, directory, class_))
      for imgName in tqdm(imageNames):
        img = load_img(os.path.join(dataDir, directory, class_, imgName), target_size=(224, 224), color_mode='rgb', interpolation='lanczos')
        img_array = img_to_array(img, data_format='channels_last', dtype='float32')
        images.append(img_array)
        labels.append(2)
    elif class_ == '3:COVID19':
      print('Reading Data for {} class'.format(class_))
      imageNames = os.listdir(os.path.join(dataDir, directory, class_))
      for imgName in tqdm(imageNames):
        img = load_img(os.path.join(dataDir, directory, class_, imgName), target_size=(224, 224), color_mode='rgb', interpolation='lanczos')
        img_array = img_to_array(img, data_format='channels_last', dtype='float32')
        images.append(img_array)
        labels.append(3)
  
  images = np.array(images).reshape(-1, 224, 224, 3)
  print('{} Data: {}'.format(directory, images.shape))
  labels = np.array(labels)
  print('{} Labels: {}'.format(directory, labels.shape))
  np.save('./datasets/{}_images'.format(directory), images)
  np.save('./datasets/{}_labels'.format(directory), labels)


for directory in directories:
    if directory=='train':
      Read_Images_and_Make_Numpy_Files(directory)
    elif directory=='test':
      Read_Images_and_Make_Numpy_Files(directory)
# Out:
# test Directory Classes: ['0:Normal', '1:Bacteria', '2:Viral', '3:COVID19']
# Reading Data for 0:Normal class
# HBox(children=(IntProgress(value=0, max=234), HTML(value='')))
# Reading Data for 1:Bacteria class
# HBox(children=(IntProgress(value=0, max=246), HTML(value='')))
# Reading Data for 2:Viral class
# HBox(children=(IntProgress(value=0, max=149), HTML(value='')))
# Reading Data for 3:COVID19 class
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# test Data: (639, 224, 224, 3)
# test Labels: (639,)
# train Directory Classes: ['0:Normal', '1:Bacteria', '2:Viral', '3:COVID19']
# Reading Data for 0:Normal class
# HBox(children=(IntProgress(value=0, max=1349), HTML(value='')))
# Reading Data for 1:Bacteria class
# HBox(children=(IntProgress(value=0, max=2540), HTML(value='')))
# Reading Data for 2:Viral class
# HBox(children=(IntProgress(value=0, max=1355), HTML(value='')))
# Reading Data for 3:COVID19 class
# HBox(children=(IntProgress(value=0, max=66), HTML(value='')))
# train Data: (5310, 224, 224, 3)
# train Labels: (5310,)

# %%
labels
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0a1df294b701> in <module>()
# ----> 1 labels
#
# NameError: name 'labels' is not defined
